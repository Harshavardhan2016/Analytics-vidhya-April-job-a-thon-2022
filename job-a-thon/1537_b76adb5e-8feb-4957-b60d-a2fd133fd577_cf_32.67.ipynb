# %% [markdown]
# ##  Importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Reading train, test data sets

# %%
train= pd.read_csv("train_E1GspfA.csv")

# %%
test=pd.read_csv("test_6QvDdzb.csv")

# %%
ran=pd.read_csv("sample_4E0BhPN.csv")

# %%
train.shape,test.shape,ran.shape   # shape of data sets
# Out:
# ((18247, 3), (7650, 2), (7650, 3))

# %%
train.info() # gives nulls and dtypes etc.. in info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18247 entries, 0 to 18246
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    18247 non-null  object
#  1   hour    18247 non-null  int64
#  2   demand  18247 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 427.8+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7650 entries, 0 to 7649
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    7650 non-null   object
#  1   hour    7650 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 119.7+ KB

# %% [markdown]
# ## converting to date time from string

# %%
train['date']=pd.to_datetime(train['date'],format='%Y-%m-%d',errors='coerce') 

train['date'].max(),train['date'].min()
# Out:
# (Timestamp('2021-02-28 00:00:00'), Timestamp('2018-08-18 00:00:00'))

# %%
test['date']=pd.to_datetime(test['date'],format='%Y-%m-%d',errors='coerce')

test['date'].max(),test['date'].min()
# Out:
# (Timestamp('2022-03-28 00:00:00'), Timestamp('2021-03-01 00:00:00'))

# %%
entry=train['date'].value_counts().to_dict()
train['entry'] = train['date'].map(entry)

# cant map so not using as feature

# %%
entry=test['date'].value_counts().to_dict()
test['entry'] = test['date'].map(entry)

# %% [markdown]
# ## deriving new features from date

# %%
train['Month']=train['date'].dt.month
train['day']=train['date'].dt.day
train['day_week']=train['date'].dt.weekday
train['quarter']=train['date'].dt.quarter
train['week']=train['date'].dt.week
train['year']=train['date'].dt.year
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_252/2881175223.py:5: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   train['week']=train['date'].dt.week

# %%
test['Month']=test['date'].dt.month
test['day']=test['date'].dt.day
test['day_week']=test['date'].dt.weekday
test['quarter']=test['date'].dt.quarter
test['week']=test['date'].dt.week
test['year']=test['date'].dt.year
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_252/511191263.py:5: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   test['week']=test['date'].dt.week

# %% [markdown]
# ## Feature making

# %%
hm=train.groupby(['hour'])['demand'].mean().to_dict()
hs=train.groupby(['hour'])['demand'].std().to_dict()

train['hm']=train['hour'].map(hm)
test['hm']=test['hour'].map(hm)

train['hs']=train['hour'].map(hs)
test['hs']=test['hour'].map(hs)

# %%
mm=train.groupby(['Month'])['demand'].mean().to_dict()
ms=train.groupby(['Month'])['demand'].std().to_dict()

train['mm'] = train['Month'].map(mm)
train['ms'] = train['Month'].map(ms)

test['mm'] = test['Month'].map(mm)
test['ms'] = test['Month'].map(ms)

# %%
dm=train.groupby(['day'])['demand'].mean().to_dict()
ds=train.groupby(['day'])['demand'].std().to_dict()

train['dm'] = train['day'].map(dm)
train['ds'] = train['day'].map(ds)

test['dm'] = test['day'].map(dm)
test['ds'] = test['day'].map(ds)

# %%
wm=train.groupby(['week'])['demand'].mean().to_dict()
ws=train.groupby(['week'])['demand'].std().to_dict()

train['wm']=train['week'].map(wm)
test['wm']=test['week'].map(wm)

train['ws']=train['week'].map(ws)
test['ws']=test['week'].map(ws)

# %%
qm=train.groupby(['quarter'])['demand'].mean().to_dict()
qs=train.groupby(['quarter'])['demand'].std().to_dict()

train['qm']=train['quarter'].map(qm)
test['qm']=test['quarter'].map(qm)

train['qs']=train['quarter'].map(qs)
test['qs']=test['quarter'].map(qs)

# %%
dwm=train.groupby(['day_week'])['demand'].mean().to_dict()
dws=train.groupby(['day_week'])['demand'].std().to_dict()

train['dwm']=train['day_week'].map(dwm)
test['dwm']=test['day_week'].map(dwm)

train['dws']=train['day_week'].map(dws)
test['dws']=test['day_week'].map(dws)

# %%
hem=train.groupby(['hour'])['entry'].mean().to_dict()
hes=train.groupby(['hour'])['entry'].std().to_dict()

train['hem']=train['hour'].map(hem)
test['hem']=test['hour'].map(hem)

train['hes']=train['hour'].map(hes)
test['hes']=test['hour'].map(hes)

# %%
train.describe()
# Out:
#                hour        demand         entry         Month           day  \
# count  18247.000000  18247.000000  18247.000000  18247.000000  18247.000000
# mean      12.614731     73.991451     20.676659      6.470324     15.782430
# std        6.544963     41.678988      2.201813      3.618189      8.772904
# min        0.000000      1.000000      7.000000      1.000000      1.000000
# 25%        8.000000     43.000000     20.000000      3.000000      8.000000
# 50%       13.000000     71.000000     21.000000      7.000000     16.000000
# 75%       18.000000     98.000000     22.000000     10.000000     23.000000
# max       23.000000    379.000000     24.000000     12.000000     31.000000
#
#            day_week       quarter          week          year            hm  \
# count  18247.000000  18247.000000  18247.000000  18247.000000  18247.000000
# mean       3.025867      2.501233     26.543706   2019.396997     73.991451
# std        2.003638      1.167955     15.828694      0.810979     15.100602
# min        0.000000      1.000000      1.000000   2018.000000     49.097633
# 25%        1.000000      1.000000     12.000000   2019.000000     59.585608
# 50%        3.000000      3.000000     27.000000   2019.000000     70.292824
# 75%        5.000000      4.000000     41.000000   2020.000000     90.743243
# max        6.000000      4.000000     53.000000   2021.000000     94.625843
#
#        ...            dm            ds            wm            ws  \
# count  ...  18247.000000  18247.000000  18247.000000  18247.000000
# mean   ...     73.991451     41.205150     73.991451     39.056062
# std    ...      3.599753      5.400087     11.160408      9.573143
# min    ...     67.919540     33.456105     61.539846     29.990930
# 25%    ...     71.407407     36.906114     67.033210     34.011967
# 50%    ...     73.618033     39.254850     72.254717     35.978753
# 75%    ...     76.203390     45.373722     75.300699     40.738477
# max    ...     80.541391     54.907973    115.466667     77.099825
#
#                  qm            qs           dwm           dws           hem  \
# count  18247.000000  18247.000000  18247.000000  18247.000000  18247.000000
# mean      73.991451     40.992535     73.991451     40.743717     20.676659
# std        4.999779      5.659656      6.978015      5.380474      0.347014
# min       66.088563     36.374633     67.307332     35.780227     20.417040
# 25%       73.995521     36.374633     67.817154     36.062620     20.455982
# 50%       73.995521     36.696306     69.675940     38.727055     20.517084
# 75%       80.152714     49.856023     80.791619     44.814939     20.756824
# max       80.152714     49.856023     86.809936     51.442955     21.815331
#
#                 hes
# count  18247.000000
# mean       2.168670
# std        0.173814
# min        1.795560
# 25%        2.007544
# 50%        2.219239
# 75%        2.319496
# max        2.371468
#
# [8 rows x 23 columns]

# %%
x=train[train['hour']==0]

# %%
x['date'].dt.year.value_counts()
# Out:
# 2019    298
# 2020    293
# 2018     83
# 2021     52
# Name: date, dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
train.columns,test.columns
# Out:
# (Index(['date', 'hour', 'demand', 'entry', 'Month', 'day', 'day_week',
#         'quarter', 'week', 'year', 'hm', 'hs', 'mm', 'ms', 'dm', 'ds', 'wm',
#         'ws', 'qm', 'qs', 'dwm', 'dws', 'hem', 'hes'],
#        dtype='object'),
#  Index(['date', 'hour', 'entry', 'Month', 'day', 'day_week', 'quarter', 'week',
#         'year', 'hm', 'hs', 'mm', 'ms', 'dm', 'ds', 'wm', 'ws', 'qm', 'qs',
#         'dwm', 'dws', 'hem', 'hes'],
#        dtype='object'))

# %%
X=train.drop(['demand','date'],axis=1)

# %%
y=train['demand']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18247 entries, 0 to 18246
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   hour      18247 non-null  int64
#  1   entry     18247 non-null  int64
#  2   Month     18247 non-null  int64
#  3   day       18247 non-null  int64
#  4   day_week  18247 non-null  int64
#  5   quarter   18247 non-null  int64
#  6   week      18247 non-null  int64
#  7   year      18247 non-null  int64
#  8   hm        18247 non-null  float64
#  9   hs        18247 non-null  float64
#  10  mm        18247 non-null  float64
#  11  ms        18247 non-null  float64
#  12  dm        18247 non-null  float64
#  13  ds        18247 non-null  float64
#  14  wm        18247 non-null  float64
#  15  ws        18247 non-null  float64
#  16  qm        18247 non-null  float64
#  17  qs        18247 non-null  float64
#  18  dwm       18247 non-null  float64
#  19  dws       18247 non-null  float64
#  20  hem       18247 non-null  float64
#  21  hes       18247 non-null  float64
# dtypes: float64(14), int64(8)
# memory usage: 3.1 MB

# %% [markdown]
# ## Features

# %%
feats=['hour' ,
#        'entry', 
       'Month', 'day', 'day_week',#'year',
      'quarter', #'week',
       'hm','hs',#'dm','ds'
      ]

# %% [markdown]
# ## Linear regression

# %% [raw]
# from sklearn.linear_model import LinearRegression
# base_model = LinearRegression()
# base_model.fit(train[feats], y)

# %% [raw]
# y_predict = base_model.predict(test[feats])

# %% [raw]
# # test['demand']=y_predict

# %% [raw]
# y_pred = base_model.predict(train[feats])
#
# from sklearn.metrics import mean_squared_error
# mean_squared_error(y_pred, y, squared=False)

# %% [raw]
# test

# %% [markdown]
# ## Decision tree

# %% [raw]
# from sklearn.tree import DecisionTreeRegressor
# regressor = DecisionTreeRegressor(random_state=0 , max_depth=5)

# %% [raw]
# dec=regressor.fit(train[feats], y)

# %% [raw]
# y_predict = dec.predict(test[feats])
# y_pred_dec = dec.predict(train[feats])

# %% [raw]
# from sklearn.metrics import mean_squared_error
# mean_squared_error(y_pred_dec, y, squared=False)

# %% [raw]
# test['demand']=y_predict
# test

# %% [markdown]
# ##  Random forest regressor

# %% [raw]
# from sklearn.ensemble import RandomForestRegressor
# random=RandomForestRegressor()

# %% [raw]
# rand=random.fit(train[feats],y)
# y_predict=rand.predict(test[feats])

# %% [raw]
# y_pred_rand=rand.predict(train[feats])
# from sklearn.metrics import mean_squared_error
# mean_squared_error(y_pred_rand, y, squared=False)

# %% [raw]
# test['demand']=y_predict

# %%
train.columns
# Out:
# Index(['date', 'hour', 'demand', 'entry', 'Month', 'day', 'day_week',
#        'quarter', 'week', 'year', 'hm', 'hs', 'mm', 'ms', 'dm', 'ds', 'wm',
#        'ws', 'qm', 'qs', 'dwm', 'dws', 'hem', 'hes'],
#       dtype='object')

# %%
feats=['hour' ,
#        'entry', 
       'Month', 'day', 'day_week',#'year',
      'quarter', #'week',
       'hm','hs',#'dm','ds'
      ]

# %%
import lightgbm as lgb
# lgb_model = lgb.LGBMRegressor(max_depth=2,num_leaves = 3,n_estimators = 20)
# lgb_model = lgb.LGBMRegressor(objective='quantile',alpha=0.5)
lgb_model = lgb.LGBMRegressor(learning_rate=0.151,n_estimators=75)
lgb_model.fit(train[feats],y)
# Out:
# LGBMRegressor(learning_rate=0.151, n_estimators=75)

# %%
out=lgb_model.predict(test[feats])
test['demand']=out

# %%
y_pred_lgb=lgb_model.predict(train[feats])
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred_lgb, y, squared=False)
# Out:
# 30.972489000020488

# %%
feat_importances = pd.Series(lgb_model.feature_importances_, index=train[feats].columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %%
feat_importances.nlargest(15).index.to_list()
# Out:
# ['day', 'Month', 'day_week', 'hour', 'hm', 'hs', 'quarter']

# %% [raw]
# from xgboost import XGBRegressor
# xgb = XGBRegressor()
# xgb.fit(train[feats],y)

# %% [raw]
# y_pred_xgb=xgb.predict(train[feats])
# from sklearn.metrics import mean_squared_error
# mean_squared_error(y_pred_xgb, y, squared=False)

# %% [raw]
# from catboost import CatBoostRegressor
# cat= CatBoostRegressor()
# cat.fit(train[feats],y)

# %% [raw]
# y_pred_cat=cat.predict(train[feats])
# from sklearn.metrics import mean_squared_error
# mean_squared_error(y_pred_cat, y, squared=False)

# %% [raw]
# y_predlgbm=lgb_model.predict(test1[feats])

# %% [raw]
# y_predl=lgb_model.predict(train[feats])

# %% [raw]
# test['demand']=y_predlgbm

# %% [markdown]
# ## Output

# %%
new=test[['date','hour','demand']]

new.to_csv('lgbmf1.csv',index=False)

# %%
## output made by lgbm model.
